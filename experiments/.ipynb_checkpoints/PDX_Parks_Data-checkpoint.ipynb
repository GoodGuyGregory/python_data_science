# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pdxParkData = pd.read_csv("./data/Parks.csv")
pdxParkData.head()
# Out:
#    OBJECTID  PROPERTYID               NAME      ACRES  Shape_Length  \
# 0         1          48  Albert Kelly Park  12.086152   1439.252170
# 1         2          49       Alberta Park  16.403797   1597.320137
# 2         3          51    April Hill Park  10.122265   1454.650781
# 3         4          52   Arbor Lodge Park   8.691468   1089.424844
# 4         5          53         Argay Park   8.928252   1172.208302
#
#       Shape_Area
# 0   99517.684997
# 1  135441.949786
# 2   83301.344632
# 3   71783.775744
# 4   73684.911851

# %%
# displ

# %%
pdxParkNames = pdxParkData[['NAME','PROPERTYID']]
# get the exact property name
pdxParkNames[pdxParkNames['PROPERTYID']==1385]
# Out:
#                          NAME  PROPERTYID
# 154  Elizabeth Caruthers Park        1385

# %%
# get tree data per park.
parkTreeInventory = pd.read_csv("./data/Parks_Tree_Inventory.csv")
parkTreeInventory.head()
# Out:
#               X             Y  OBJECTID          Inventory_Date Species   DBH  \
# 0 -1.365819e+07  5.712487e+06       426  2017/05/09 00:00:00+00    PSME  37.4
# 1 -1.365821e+07  5.712485e+06       427  2017/05/09 00:00:00+00    PSME  32.5
# 2 -1.365825e+07  5.712491e+06       428  2017/05/09 00:00:00+00    CRLA   9.7
# 3 -1.365823e+07  5.712487e+06       429  2017/05/09 00:00:00+00    QURU  10.3
# 4 -1.365823e+07  5.712488e+06       430  2017/05/09 00:00:00+00    PSME  33.2
#
#   Condition  TreeHeight  CrownWidthNS  CrownWidthEW  ...       Common_name  \
# 0      Fair       105.0          44.0          57.0  ...       Douglas-fir
# 1      Fair        94.0          49.0          45.0  ...       Douglas-fir
# 2      Fair        23.0          28.0          27.0  ...  Lavalle hawthorn
# 3      Poor        28.0          38.0          31.0  ...  northern red oak
# 4      Fair       102.0          43.0          44.0  ...       Douglas-fir
#
#            Genus_species  Functional_type Size Native Edible Nuisance  \
# 0  Pseudotsuga menziesii               CE    L    Yes    NaN      NaN
# 1  Pseudotsuga menziesii               CE    L    Yes    NaN      NaN
# 2  Crataegus x lavalleei               BD    S     No    NaN      NaN
# 3          Quercus rubra               BD    L     No    NaN      NaN
# 4  Pseudotsuga menziesii               CE    L    Yes    NaN      NaN
#
#                                               Origin  \
# 0  North America - from British Columbia south to...
# 1  North America - from British Columbia south to...
# 2  North America - a hybrid between a Mexican and...
# 3  North America - eastern Canada and eastern USA...
# 4  North America - from British Columbia south to...
#
#                                      Species_factoid  PropertyID
# 0  Bracts on cones look like a mouse's feet and t...       137.0
# 1  Bracts on cones look like a mouse's feet and t...       137.0
# 2  Like most hawthorns, the tree has stout thorns...       137.0
# 3  Acorns take two years to mature and are an imp...       137.0
# 4  Bracts on cones look like a mouse's feet and t...       137.0
#
# [5 rows x 42 columns]

# %%
# pull property id numbers and determine match
treeParks = parkTreeInventory['PropertyID']

treeProperties = treeParks.unique()

unique_properties = pd.DataFrame(treeProperties, columns=['ParkID'])
# calling to string will display all of the available park ids
# print(unique_properties.to_string())

# drops Nan in row 72
# 21965 -1.365664e+07  5.703584e+06    637190  2019/09/03 00:00:00+00    STJA
# 21981 -1.365655e+07  5.703611e+06    637586  2019/09/03 00:00:00+00    CUSE
#
#        DBH Condition  TreeHeight  CrownWidthNS  CrownWidthEW  ...  \
# 21923  2.8      Good        13.0           4.0           4.0  ...
# 21924  1.9      Good        10.0           9.0           9.0  ...
# 21925  1.9      Good         8.0           9.0          10.0  ...
# 21944  1.9      Good         9.0           9.0           8.0  ...
# 21945  1.9      Good         7.0          12.0           8.0  ...
# 21962  2.8      Fair        13.0           4.0           4.0  ...
# 21963  1.9      Good         9.0           9.0           9.0  ...
# 21964  1.9      Good         9.0           8.0           7.0  ...
# 21965  1.9      Good         9.0           7.0           8.0  ...
# 21981  2.8      Good        14.0           4.0           4.0  ...
#
#              Common_name           Genus_species  Functional_type Size Native  \
# 21923    Italian cypress  Cupressus sempervirens               CE    M     No
# 21924  Japanese snowbell        Styrax japonicus               BD    S     No
# 21925  Japanese snowbell        Styrax japonicus               BD    S     No
# 21944  Japanese snowbell        Styrax japonicus               BD    S     No
# 21945  Japanese snowbell        Styrax japonicus               BD    S     No
# 21962    Italian cypress  Cupressus sempervirens               CE    M     No
# 21963  Japanese snowbell        Styrax japonicus               BD    S     No
# 21964  Japanese snowbell        Styrax japonicus               BD    S     No
# 21965  Japanese snowbell        Styrax japonicus               BD    S     No
# 21981    Italian cypress  Cupressus sempervirens               CE    M     No
#
#       Edible Nuisance                                             Origin  \
# 21923    NaN      NaN  Africa, Asia, Europe - Iran, Syria, Israel, Le...
# 21924    NaN      NaN                         Asia - Japan, Korea, China
# 21925    NaN      NaN                         Asia - Japan, Korea, China
# 21944    NaN      NaN                         Asia - Japan, Korea, China
# 21945    NaN      NaN                         Asia - Japan, Korea, China
# 21962    NaN      NaN  Africa, Asia, Europe - Iran, Syria, Israel, Le...
# 21963    NaN      NaN                         Asia - Japan, Korea, China
# 21964    NaN      NaN                         Asia - Japan, Korea, China
# 21965    NaN      NaN                         Asia - Japan, Korea, China
# 21981    NaN      NaN  Africa, Asia, Europe - Iran, Syria, Israel, Le...
#
#                                          Species_factoid  PropertyID
# 21923  Narrowest conifer tree in Portland to 3' wide....       515.0
# 21924  Fruit looks like an upside down golf ball sitt...       515.0
# 21925  Fruit looks like an upside down golf ball sitt...       515.0
# 21944  Fruit looks like an upside down golf ball sitt...       515.0
# 21945  Fruit looks like an upside down golf ball sitt...       515.0
# 21962  Narrowest conifer tree in Portland to 3' wide....       515.0
# 21963  Fruit looks like an upside down golf ball sitt...       515.0
# 21964  Fruit looks like an upside down golf ball sitt...       515.0
# 21965  Fruit looks like an upside down golf ball sitt...       515.0
# 21981  Narrowest conifer tree in Portland to 3' wide....       515.0
#
# [10 rows x 42 columns]

# %%
#  all unique trees inventoried
allTrees = parkTreeInventory['Common_name'].unique()
print(allTrees)
# Out:
# ['Douglas-fir' 'Lavalle hawthorn' 'northern red oak' 'common hackberry'
#  'flowering plum' 'eastern redbud' 'ornamental crabapple'
#  'saucer magnolia' 'paperbark maple' 'European ash' 'white ash'
#  'Norway maple' 'snakebark maple' 'giant sequoia' 'Japanese zelkova'
#  'tuliptree' 'silver maple' 'pin oak' 'Siberian elm' 'paper birch'
#  'Amur maackia' 'Oregon ash' 'narrowleaf ash' 'black cottonwood'
#  'European white birch' 'southern magnolia' 'flowering pear' 'hedge maple'
#  'Hungarian oak, Italian oak' 'red maple' 'elm hybrid' 'sweetgum'
#  'bigleaf maple' 'western redcedar' 'European beech' 'flowering ash'
#  'eastern dogwood' 'willow oak' 'unknown (dead)' 'dawn redwood'
#  'London plane tree' 'bur oak' 'American elm' 'Norway spruce'
#  'ponderosa pine' 'cherry' 'incense cedar' 'dogwood' 'katsura' 'red alder'
#  'largeleaf linden' 'paperbark cherry, birchbark cherry, Tibetan cherry'
#  'kousa dogwood' 'Japanese flowering cherry' 'scarlet oak' 'green ash'
#  'privet' 'larch' 'American hornbeam, blue beech' 'English holly'
#  'mountain ash or whitebeam' 'European pear (including cultivars)'
#  'paulownia, Empress tree, foxglove tree' 'black tupelo'
#  'Oregon white oak' 'Spanish chestnut' 'Scots pine' 'sawtooth oak'
#  'black locust' 'Colorado blue spruce' 'red-silver maple hybrid'
#  'western hemlock' 'willow' 'sugar maple' 'Harlequin glory bower'
#  'littleleaf linden' 'English walnut' 'cornelian cherry' 'bald cypress'
#  'deodar cedar' 'English laurel, cherry laurel'
#  'English hawthorn, common hawthorn' 'tree of heaven' 'ash'
#  'common horsechestnut' 'river birch' 'mountain hemlock' 'plum'
#  'Turkish hazel' 'Pacific dogwood' 'Amur maple'
#  'shore pine, lodgepole pine' 'Alaska yellow-cedar' 'golden larch'
#  'Italian cypress' 'grand fir' 'Japanese maple' 'Austrian black pine'
#  'Pacific madrone' 'English oak' 'dove or handkerchief tree'
#  'black hawthorn' 'Himalayan whitebarked birch' 'European aspen'
#  'apple (MADO)' 'serviceberry'
#  'Japanese pagoda tree, Chinese scholar tree' 'ginkgo' 'honey locust'
#  'American linden' 'Rocky Mountain Glow maple' 'vine maple' 'crape myrtle'
#  'blue Atlas cedar' 'strawberry tree' 'sycamore maple' 'northern catalpa'
#  'Hinoki falsecypress' 'Brewer spruce' 'silver linden' 'sweetbay'
#  'mulberry' 'black walnut' 'eastern white pine' 'magnolia'
#  'Port Orford cedar' 'European hornbeam' 'hiba arborvitae, thujopsis'
#  'Kentucky coffeetree' 'Oregon myrtle' 'European mountain ash'
#  'Pacific silver fir' 'midland hawthorn, English hawthorn'
#  'western white pine' 'coast redwood' 'Japanese red pine'
#  'American sycamore' 'bird cherry' 'Portugal laurel, Portuguese laurel'
#  'goldenrain tree' 'persimmon' 'mountain silverbell' 'eastern cotonwood'
#  'black poplar, Lombardy poplar' 'weeping willow' 'yellow buckeye'
#  'Japanese tree lilac' 'red horsechestnut' 'Ohio buckeye'
#  'Persian ironwood' 'Amur cork tree' 'chinkapin oak' 'star magnolia'
#  'Japanese hornbeam' 'swamp white oak' 'white spruce' 'Prunus species'
#  'cedar of Lebanon' 'Caucasian fir, Nordmann fir' 'Jeffrey pine'
#  'white fir' 'Japanese cedar' 'Japanese stewartia' 'juniper'
#  'Japanese snowbell' 'American smoketree' 'noble fir' 'hazel, filbert'
#  'witch hazel' 'longleaf pine' 'pine' 'horsechestnuts, buckeyes'
#  'Chinese tupelo' 'silk tree' 'eastern white oak'
#  'bigleaf snowbell, fragrant snowbell' 'shagbark hickory'
#  'hazel or hazelnut' 'cascara buckthorn' 'American yellowwood'
#  'oyama magnolia' 'boxleaf azara' 'southern live oak'
#  'Hardy Chinese rubber tree, eucommia' 'sourwood' 'trident maple'
#  'cypress' 'pear' 'Coulter pine' 'cucumber magnolia' 'Seven-son plant'
#  'winged elm' "Chinese evergreen magnolia, Delavay's magnolia"
#  'Japanese bay tree' 'yulan magnolia' 'Daphniphyllum' 'lacebark pine'
#  'Japanese white pine' 'fragrant olive' 'smiling monkey tree'
#  'Japanese black pine' 'Japanese apricot' 'Yellow Lily-tree'
#  'umbrella pine' 'Japanese blueberry tree' 'Chusan palm or windmill palm'
#  'Buddhist pine, yew pine' 'evergreen dogwood' 'wheel tree' 'camphor tree'
#  "Martin's magnolia" 'false ginseng' 'Zen magnolia'
#  'Japanese persimmon, Asian persimmon' 'Schima'
#  'Japanese emperor oak, daimyo oak' 'ring-cupped oak, Japanese blue oak'
#  'Phoebe' 'China fir' 'tubeflower viburnum' 'lusterleaf holly' 'loquat'
#  'Monpellier maple' 'Chinese fringe tree' 'box elder' 'elm' 'field elm'
#  'southern catalpa' 'Aleppo pine' 'giant dogwood'
#  'Franklin tree, franklinia' 'quaking aspen' 'Shumard oak'
#  'arborvitae, eastern arborvitae, northern white-cedar' 'butternut'
#  'Korean fir' 'Camperdown elm' 'limber pine' 'holly oak, holm oak'
#  'netleaf hackberry' 'silverleaf oak' "Sargent's cherry"
#  'Chinese paper birch' "Campbell's magnolia" 'European larch' 'black oak'
#  'English yew' 'Serbian spruce' 'American hophornbeam' 'Mexican pinyon'
#  'Pacific yew' "Ashe's magnolia, dwarf bigleaf magnolia"
#  'orange-bark stewartia, tall stewartia' 'Washington hawthorn'
#  'Chinese horsechestnut' 'Chinese pistache' 'Guangdong pine'
#  "Henry anise tree, Henry's star anise" 'coast live oak' 'American beech'
#  'sugarberry, southern hackberry' 'Spanish fir' 'Accolade elm'
#  'Chinese lacebark elm' 'Swedish whitebeam' 'Sitka spruce'
#  'Asian pear, sand pear' 'Allegheny serviceberry' 'common fig'
#  'sawara cypress' 'falsecypress' 'leatherwood' 'Himalayan white pine'
#  'fir' 'American persimmon' 'water oak' 'California buckeye'
#  'western larch' 'Himalayan spruce' 'wingnut' 'Balkan maple'
#  'Leuteneggeri hybrid fir' 'Pacific crabapple' 'pecan' 'fullmoon maple'
#  "Hartweg's pine" 'Leyland cypress' 'corkscrew willow' 'hornbeam'
#  'Hainan white pine, Kwangtung pine' 'spindle-tree' 'European silver fir'
#  'cork oak' 'Oriental spruce' 'red lotus tree' 'Chinese parasol tree'
#  'redvein maple' 'mu gua hong' 'Rocky mountain bristlecone pine'
#  'Japanese hemlock' 'chitalpa' 'valley oak' 'golden chinkapin'
#  'goldenchain tree']

# %%
# Questions to Answer:

# which park has the tallest douglas-fir?
# Common_name = 'Douglas-fir'

parksWithDouglasFirs = parkTreeInventory[parkTreeInventory['Common_name'] == 'Douglas-fir']
tallestDouglasFirPark = parksWithDouglasFirs[['PropertyID','TreeHeight']].max()

# tallestPark = tallestDouglasFirPark['PropertyID']

# parkName = parksInventoried[parksInventoried['ParkID'] == tallestPark]
# print(parkName)

#which park has the largest and tallest collection of douglas-fir?

parksWithDouglasFirs = parkTreeInventory[parkTreeInventory['Common_name'] == 'Douglas-fir'][['PropertyID','TreeHeight']]
# without max this will show the largest collection of douglas-firs with the park id
parksWithDouglasFirs['PropertyID'].value_counts().max()
#  gets the grouped properties by mean value for tree heights 
parksWithTallDFirs = parksWithDouglasFirs.groupby('PropertyID').mean()
# displays park ID = 1196.0
parkName = parksInventoried[parksInventoried['ParkID'] == 1196.0]
# print(parkName)

# which of these parks that contain the tallest trees is the largest?
# get the top 25 parks with the max counts of douglas firs
# print(parksWithDouglasFirs['PropertyID'].value_counts().head(25))

largestCollectionDougFirs = parksWithDouglasFirs['PropertyID'].value_counts().head(25)


# confirm 25
len(largestCollectionDougFirs)
# this gets the parkIds for searching 
parkList = largestCollectionDougFirs.index

# this is the list of parks with the largest collection of Douglas-Firs 
largestParksWithLargestCollection = parksInventoried[parksInventoried['ParkID'].isin(parkList)].sort_values(by='ACRES',ascending=False)[:10]
largestParksWithLargestCollection[['NAME','ACRES','ParkID']]

treesPerPark = parkTreeInventory[parkTreeInventory['Common_name'] == 'Douglas-fir'].groupby('PropertyID').size()
treesPerPark = treesPerPark[treesPerPark.index.isin(parkList)]

# reset_index sets the new count to a column within the Series and give it a name 'DouglasFirCount'
treesPerPark = treesPerPark.reset_index(name='DouglasFirCount')

# Merge with parksInventoried to get park names
merged_df = pd.merge(treesPerPark, parksInventoried, left_on='PropertyID', right_on='ParkID', how='left')

# Select relevant columns
parkNamesDouglasFirCounts = merged_df[['NAME','DouglasFirCount']].sort_values(by='DouglasFirCount', ascending=False)      
print(parkNamesDouglasFirCounts[['NAME','DouglasFirCount']])

plt.figure(figsize=(12,8),dpi=200)
sns.barplot(x=parkNamesDouglasFirCounts['DouglasFirCount'],y=parkNamesDouglasFirCounts['NAME'])
for index, value in enumerate(parkNamesDouglasFirCounts['DouglasFirCount']):
    plt.text(value + 1, index, str(value), ha='left', va='center')

plt.title('Douglas-Fir Counts Per Park')
# Out:
#                                    NAME  DouglasFirCount
# 17                        Mt Tabor Park              696
# 1                         Columbia Park              557
# 10                       John Luby Park              547
# 14                         Lincoln Park              430
# 16                        Mt Scott Park              344
# 15                       Lynchwood Park              325
# 21                        Sellwood Park              287
# 12                     Laurelhurst Park              279
# 2                          Creston Park              270
# 5                          Alberta Park              242
# 19               North Powellhurst Park              207
# 22                      Washington Park              179
# 23                        Wilshire Park              169
# 13                           Lents Park              166
# 6                      Earl Boyles Park              152
# 4                     Albert Kelly Park              136
# 20                       Peninsula Park              124
# 0                           Cherry Park              106
# 18                      Normandale Park              105
# 3   Crystal Springs Rhododendron Garden               93
# 9                          Hancock Park               88
# 24                       Woodstock Park               88
# 8                            Grant Park               83
# 11                      Kenilworth Park               82
# 7                  Gilbert Primary Park               62
# Text(0.5, 1.0, 'Douglas-Fir Counts Per Park')

# %%
# per each of these parks what is the largest tree height?
idx = parkTreeInventory[parkTreeInventory['Common_name'] == 'Douglas-fir'][['PropertyID','TreeHeight']].groupby('PropertyID')['TreeHeight'].idxmax()

tallestTreesPerPark = parkTreeInventory.loc[idx]
tallestTreesPerPark = tallestTreesPerPark[tallestTreesPerPark['PropertyID'].isin(parkList)][['TreeHeight','PropertyID']]
# print(tallestTreesPerPark)

parkNames = parksInventoried[parksInventoried['ParkID'].isin(tallestTreesPerPark['PropertyID'])][['NAME','ParkID']]
# parkNames

parkNamesTreeHeights = pd.merge(parkNames, tallestTreesPerPark, left_on='ParkID', right_on='PropertyID')
parkNamesTreeHeights = parkNamesTreeHeights.drop(['ParkID','PropertyID'], axis=1)
print(parkNamesTreeHeights)

#  display the data of max tree heights per park

plt.figure(figsize=(14,8),dpi=200)
sns.barplot(x=parkNamesTreeHeights['NAME'],y=parkNamesTreeHeights['TreeHeight'])
plt.xticks(rotation=90)
# iterates over each bar from the TreeHeight index and adds the value to the bar 
# with a (Horizontal Alignment) = Center, and (Vertical Alginment) = Bottom
for index, value in enumerate(parkNamesTreeHeights['TreeHeight']):
    plt.text(index, value + 4, str(value), ha='center', va='bottom')
plt.ylim(0, 200)
plt.title('Tallest Douglas-Fir in Park')
# Out:
#                                    NAME  TreeHeight
# 0                     Albert Kelly Park       143.0
# 1                          Alberta Park       143.0
# 2                         Columbia Park       174.0
# 3                          Creston Park       158.0
# 4   Crystal Springs Rhododendron Garden       153.0
# 5                            Grant Park       144.0
# 6                          Hancock Park       148.0
# 7                        John Luby Park       151.0
# 8                       Kenilworth Park       153.0
# 9                            Lents Park       150.0
# 10                       Lynchwood Park       168.0
# 11                        Mt Scott Park       168.0
# 12                        Mt Tabor Park       190.0
# 13                      Normandale Park       130.0
# 14               North Powellhurst Park       150.0
# 15                       Peninsula Park       140.0
# 16                        Sellwood Park       184.0
# 17                        Wilshire Park       144.0
# 18                       Woodstock Park       148.0
# 19                         Lincoln Park       151.0
# 20                          Cherry Park       141.0
# 21                      Washington Park       177.0
# 22                     Earl Boyles Park       136.0
# 23                 Gilbert Primary Park       156.0
# 24                     Laurelhurst Park       176.0
# Text(0.5, 1.0, 'Tallest Douglas-Fir in Park')

# %%
# where are the most ponderosa pines?

# are there any parks with western juniper trees?

# which park has the most cherry trees?

# which park has the most big leaf maples?

    # where is the tallest?      

# which park has the tallest white oaks?

# which park has the most rhododendrons?

# which park has the most magnolias?

# which park has the most dogwoods?

# which park has the most witchhazel?

# which park has the most ginko trees?
